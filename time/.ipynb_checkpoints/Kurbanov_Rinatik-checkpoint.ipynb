# %%
import pandas as pd 
import datetime
import numpy as np 
import matplotlib.pyplot as plt 
import statsmodels.api as sm
from pylab import rcParams
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
from itertools import product
import warnings

# %matplotlib inline

# %%
train=pd.read_csv('train.csv', sep=',').dropna()

# %%
train['date']=pd.to_datetime(train.date,format='%d.%m.%Y')
train.index=train.date
train.drop('date',axis=1, inplace=True)

# %%
test=pd.read_csv('test.csv', sep=',').dropna()
test['date']=pd.to_datetime(test.date,format='%d.%m.%Y')
test.index=test.date
test.drop('date',axis=1, inplace=True)

# %%
train['weekday'] = train.index.weekday
train['week'] = train.index.week
train['month']=train.index.month
train_pivot = pd.pivot_table(train, values = "orders", columns = "month", index = "weekday")
train_pivot.plot(legend = False)

# %%
train.drop(['weekday','week', 'month', 'date_id'], axis=1, inplace=True)

# %%
def test_stationarity(timeseries, window = 12, cutoff = 0.05):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window).mean()
    rolstd = timeseries.rolling(window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries.values,autolag='AIC' )
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    pvalue = dftest[1]
    if pvalue < cutoff:
        print('p-value = %.4f. The series is likely stationary.' % pvalue)
    else:
        print('p-value = %.4f. The series is likely non-stationary.' % pvalue)
    
    print(dfoutput)

# %%
test_stationarity(train[45:].orders)
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0013. The series is likely stationary.
# Test Statistic                 -4.019848
# p-value                         0.001310
# #Lags Used                     11.000000
# Number of Observations Used    39.000000
# Critical Value (1%)            -3.610400
# Critical Value (5%)            -2.939109
# Critical Value (10%)           -2.608063
# dtype: float64

# %%
import copy

# %%
train2=copy.deepcopy(train[45:])

# %%
rcParams['figure.figsize'] = 12, 7
train1['orders_diff'] = train1.orders - train1.orders.shift(1)
train1.dropna(inplace = True)
test_stationarity(train1['orders_diff'], window = 12)
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0000. The series is likely stationary.
# Test Statistic                -1.113959e+01
# p-value                        3.132499e-20
# #Lags Used                     5.000000e+00
# Number of Observations Used    8.900000e+01
# Critical Value (1%)           -3.506057e+00
# Critical Value (5%)           -2.894607e+00
# Critical Value (10%)          -2.584410e+00
# dtype: float64

# %%
train.shape
# Out:
# (96, 1)

# %%
for i in range(1,2):
    train7=copy.deepcopy(train)
    rcParams['figure.figsize'] = 12, 7
    train7['orders_diff'] = train7.orders - train7.orders.shift(i)
    train7.dropna(inplace = True)
    test_stationarity(train7['orders_diff'], window = 12)
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0000. The series is likely stationary.
# Test Statistic                -1.113959e+01
# p-value                        3.132499e-20
# #Lags Used                     5.000000e+00
# Number of Observations Used    8.900000e+01
# Critical Value (1%)           -3.506057e+00
# Critical Value (5%)           -2.894607e+00
# Critical Value (10%)          -2.584410e+00
# dtype: float64

# %%
import statsmodels.api as sm
fig, ax = plt.subplots(figsize=(20,8))
sm.graphics.tsa.plot_pacf(train7.orders_diff.values, lags=25,ax = ax)
plt.show()
# Out:
# C:\Users\vkrin\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
import statsmodels.api as sm
fig, ax = plt.subplots(figsize=(20,8))
sm.graphics.tsa.plot_pacf(train7.orders_diff.values, lags=50,ax = ax)
plt.show()
# Out:
# C:\Users\vkrin\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1275: RuntimeWarning: invalid value encountered in double_scalars
#   r[k] = (X[0:-k] * X[k:]).sum() / denom(k)

# %%
fig, ax = plt.subplots(figsize=(20,8))
sm.graphics.tsa.plot_acf(train7.orders_diff.values, lags=40,ax = ax)
plt.show()

# %%
d = 0
D = 0
s = 1

ps = range(0, 8)
qs = range(0, 4)
Ps =range(0,4)
Qs = range(0, 4)

# %%
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 512

# %%
# %%time
import warnings
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')

for param in parameters_list:
    #try except нужен, потому что на некоторых наборах параметров модель не обучается
    try:
        model=sm.tsa.statespace.SARIMAX(train2.orders, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], s)).fit(disp=-1)
    #выводим параметры, на которых модель не обучается и переходим к следующему набору
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    #сохраняем лучшую модель, aic, параметры
    if aic < best_aic:
        best_model = model
        print(model.summary().tables[0])
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    
warnings.filterwarnings('default')
#воспроизвести не получается, не помню, но ниже модель та, при помощи которой добился большого скора.
#Воспользовался вашей идеей, убрал часть данных
# Out:
#                            Statespace Model Results
# ...
# Dep. Variable:                 orders   No. Observations:                   56
# Model:                        SARIMAX   Log Likelihood                -287.739
# Date:                Wed, 24 Apr 2019   AIC                            577.478
# Time:                        00:16:15   BIC                            579.504
# Sample:                    02-05-2019   HQIC                           578.263
#                          - 04-01-2019
# Covariance Type:                  opg
# ...
#                             Statespace Model Results
# ...
# Dep. Variable:                  orders   No. Observations:                   56
# Model:             SARIMAX(0, 0, 1, 1)   Log Likelihood                -260.021
# Date:                 Wed, 24 Apr 2019   AIC                            524.042
# Time:                         00:16:15   BIC                            528.093
# ...

# %%
model=sm.tsa.statespace.SARIMAX(train2.orders, order=(6, d, 2), 
                                        seasonal_order=(0, D, 3, 1)).fit(disp=-1)

# %%
plt.figure(figsize=(16,8))
plt.plot(model.resid[1:])
plt.show()

# %%
stat_test = sm.tsa.adfuller(model.resid[:])
print ('adf: ', stat_test[0] )
print ('p-value: ', stat_test[1])
print('Critical values: ', stat_test[4])
if stat_test[0]> stat_test[4]['5%']: 
    print ('есть единичные корни, ряд не стационарен')
else:
    print ('единичных корней нет, ряд стационарен')
# Out:
# adf:  -13.383894982560816
# p-value:  4.916315885750224e-25
# Critical values:  {'1%': -3.568485864, '5%': -2.92135992, '10%': -2.5986616}
# единичных корней нет, ряд стационарен

# %%
forecast = model.predict(start = train2.shape[0], end = train2.shape[0]+test.shape[0])

# %%
plt.figure(figsize=(16,8))
plt.plot(train7.orders, label='Train')
plt.plot(forecast, label='SARIMA')
plt.legend(loc='best')
plt.show()

# %%
print(forecast)
# Out:
# 2019-04-02    36.260032
# 2019-04-03    36.970153
# 2019-04-04    28.032617
# 2019-04-05    37.881230
# 2019-04-06    54.933855
# 2019-04-07    47.191853
# 2019-04-08    33.754556
# 2019-04-09    37.380264
# 2019-04-10    36.166428
# Freq: D, dtype: float64

# %%
test['orders']=forecast

# %%
test.to_csv('kr.csv', index=False)
